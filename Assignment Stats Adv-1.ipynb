# %% [raw]
# 1. Explain the properties of the F-distribution.
# Ans.
# 1.The F-distribution is positively skewed, meaning it has a long right tail. The skewness decreases as the degrees of freedom increase.
# 2.2. Parameters: Degrees of Freedom
# The F-distribution is determined by two parameters:
# Numerator degrees of freedom (d1): The degrees of freedom associated with the variance of the numerator (typically, a variance estimate from a sample).
# Denominator degrees of freedom (d2): The degrees of freedom associated with the variance of the denominator (usually, a variance estimate from another sample or population).
# 3. Mean and Variance: The mean of F-Distribution is:
#                         μ = d2/d2-2 , for d2>2.
#                     : The variance of F-distribution is:
#                         Var(F) = 2(d2)^2(d1+d1-2)/d1(d2-2)^2(d2-4), for d2>4

# %% [raw]
# 2. In which types of statistical tests is the F-distribution used, and why is it appropriate for these tests?
# Ans.
# The F-distribution is used primarily in statistical tests that involve comparing variances or assessing the ratio of variances between two or more groups. It is especially useful in tests where the underlying assumption is that the data follows a normal distribution. Here are the key types of statistical tests in which the F-distribution is used, :
#
# 1. Analysis of Variance (ANOVA)
# 2.2. Two-Sample F-test (or Variance Ratio Test)
# 3. Regression Analysis (F-test for Overall Significance)
# 4. Comparing Nested Models (Model Comparison)
# 5. Levene's Test for Equality of Variances
#
# Why the F-distribution is Appropriate:
# Ratio of Variances: The F-distribution arises when you are testing the ratio of two independent sample variances, which is a common approach in the tests listed above. If the samples are drawn from normally distributed populations, the ratio of the variances (scaled by their degrees of freedom) follows an F-distribution.
# Chi-square Relationship: Many of the statistical tests involving the F-distribution (like ANOVA or the two-sample F-test) rely on the fact that the variance estimates follow a Chi-square distribution, and the ratio of two such independent Chi-square distributions leads to an F-distribution.
# Skewed Distribution: The F-distribution is positively skewed, which makes it well-suited for testing variance ratios since, in most cases, the ratio of two variances is expected to be greater than 1 (with larger ratios indicating greater variance in the numerator group).
# Tests for Model Fit: In regression and ANOVA, the F-test provides a way to evaluate whether the variability explained by the model is significantly greater than the residual (unexplained) variability, making it useful for assessing the significance of the model as a whole.

# %% [raw]
# 3. What are the key assumptions required for conducting an F-test to compare the variances of two
# populations?
# Ans. Key Assumptions for an F-test:
# Independence of Samples: The two groups being compared must be independent.
# Normality: Both populations should be approximately normal, especially for small sample sizes.
# Random Sampling: Both samples should be randomly selected from their populations.
# Scale of Measurement: The data should be on an interval or ratio scale.
# Homogeneity of Variance: The test evaluates whether the variances of the two populations are significantly different; however, the populations must be similarly distributed in terms of variance.

# %% [raw]
# 4. What is the purpose of ANOVA, and how does it differ from a t-test?
# Ans.
# Purpose of ANOVA (Analysis of Variance)
# ANOVA (Analysis of Variance) is a statistical technique used to compare the means of three or more groups to determine whether there is a significant difference among them. The primary goal of ANOVA is to test if the means of different groups are equal or if at least one of the groups is significantly different from the others.
#
# Key Purposes of ANOVA:
# Test for differences between multiple group means: ANOVA evaluates whether the variation in sample data can be attributed to differences between group means or to random sampling variability.
# Evaluate the impact of one or more categorical independent variables (factors) on a continuous dependent variable: ANOVA is widely used in experimental designs, where you want to assess how changes in categorical factors (like treatment type, gender, etc.) affect a continuous outcome (like test scores, sales revenue, etc.).
# Analyze more complex experimental designs: ANOVA can be extended to handle more complex experimental designs, such as two-way or three-way ANOVA, which include multiple factors and allow researchers to examine interactions between different factors.

# %% [markdown]
# ![Anova.JPG](attachment:ba49270d-d3c8-4424-baeb-3eabfad03680.JPG)

# %% [raw]
# 5.Explain when and why you would use a one-way ANOVA instead of multiple t-tests when comparing more
# than two groups.
# Ans.
# a one-way ANOVA is used instead of multiple t-tests when comparing more than two groups because it controls the Type I error rate, is more efficient, and allows for a clearer, more powerful statistical test. It provides a global test of group differences, and if significant, you can follow up with post-hoc comparisons to understand where the differences lie.
#
# When comparing more than two groups, a one-way ANOVA is preferred over multiple t-tests for several important reasons:
#
# 1. Control of Type I Error Rate:
# Multiple t-tests increase the risk of committing a Type I error (false positive). The more t-tests you conduct, the higher the probability of incorrectly rejecting a true null hypothesis. This is because each individual test has a chance of producing a Type I error, and when you perform multiple tests, the overall likelihood of making at least one Type I error increases.
# For example, if you run 5 t-tests, each with a significance level of 0.05, the overall probability of a Type I error across all tests is higher than 0.05 due to the cumulative effect.
# A one-way ANOVA corrects for this problem because it evaluates all group differences simultaneously, using a single test to assess whether there is any significant difference between the groups, thus controlling the Type I error rate.
# 2. Efficient Comparison of More Than Two Groups:
# ANOVA is specifically designed for comparing more than two groups at once. A one-way ANOVA tests the null hypothesis that all group means are equal (i.e., there are no differences between the groups).
# When you use multiple t-tests for pairwise comparisons between groups, the number of tests grows quickly as the number of groups increases. For instance, with 4 groups, you'd have to run 6 pairwise t-tests, and with 5 groups, you would need 10 t-tests, and so on. Each additional test increases the chances of finding a significant result just by chance.
# 3. Statistical Power:
# ANOVA is more powerful than performing multiple t-tests because it allows you to compare all the groups at once. It uses the variance within each group and between groups to determine if there is a significant difference in means.
# Performing multiple t-tests separately does not provide a clear overall picture of how all groups compare to each other and can lead to misleading conclusions, especially if some t-tests show significant differences while others do not.
# 4. Interpretation:
# One-way ANOVA provides an overall test of whether there is any difference between the groups. If the ANOVA indicates a significant difference, you can then perform post-hoc tests (like Tukey’s HSD) to identify which specific groups differ from each other.
# If you run multiple t-tests, interpreting which groups are different becomes more complicated, and you'd still need to adjust for multiple comparisons (such as using a correction like the Bonferroni method) to avoid inflating the Type I error rate.
# 5. Assumptions of the Tests:
# The assumptions for a one-way ANOVA include normality of the groups and homogeneity of variances (i.e., the variance within each group is similar).
# t-tests can be conducted pairwise, but if you're testing multiple pairs, you risk violating assumptions regarding the distribution of data or variances across groups, especially when the number of comparisons increases.

# %% [raw]
# 6. Explain how variance is partitioned in ANOVA into between-group variance and within-group variance.
# How does this partitioning contribute to the calculation of the F-statistic?
# Ans.
# Partitioning variance in ANOVA into between-group and within-group components allows us to assess whether the variability between groups is greater than the variability within groups.
# The F-statistic is the ratio of the mean between-group variance to the mean within-group variance, and a large F-statistic suggests that the group means are not all equal, leading to the rejection of the null hypothesis in favor of the alternative that at least one group mean is different.

# %% [raw]
# The classical (frequentist) approach and the Bayesian approach to Analysis of Variance (ANOVA) are two different paradigms for statistical inference, each with its own philosophy regarding uncertainty, parameter estimation, and hypothesis testing. Below is a comparison of the key differences between them:
#
# 1. Uncertainty and Prior Knowledge
# Frequentist Approach:
#
# No prior knowledge or beliefs: In frequentist ANOVA, uncertainty is treated strictly in terms of sampling variability, and no prior distribution is used for the parameters. The model is assumed to be true, and uncertainty is reflected in the variability of the data around the model.
# Point estimates of parameters: Parameters (such as means and variances) are estimated as point estimates (e.g., sample means, variances) without any notion of prior beliefs about their values.
# Bayesian Approach:
#
# Incorporates prior beliefs: Bayesian ANOVA incorporates prior distributions for the parameters, which represent the analyst’s beliefs about the parameters before observing the data. These priors can be informative (based on previous studies or expert knowledge) or uninformative (such as a non-informative uniform or normal distribution).
# Uncertainty through probability distributions: Rather than producing single-point estimates, the Bayesian approach treats parameters as random variables with probability distributions. This means uncertainty about the parameters is captured as a spread (or variance) around the expected values.
# 2. Parameter Estimation
# Frequentist Approach:
#
# Maximum Likelihood Estimation (MLE): In frequentist ANOVA, parameters are typically estimated by maximizing the likelihood of the observed data. These estimates are usually point estimates, and their precision is assessed through confidence intervals or standard errors.
# No posterior distribution: There is no direct interpretation of uncertainty as a distribution over parameters. Instead, confidence intervals represent ranges of values that would contain the true parameter value in a large proportion of repeated samples.
# Bayesian Approach:
#
# Posterior Distribution: In the Bayesian framework, parameter estimation is based on the posterior distribution, which is computed using Bayes’ Theorem:
#
# P(θ∣data)= P(data∣θ)P(θ)/P (data)
# ​
# This combines the likelihood of the data given the parameters (likelihood function) with the prior distribution over the parameters.
# Credible Intervals: Rather than using confidence intervals, Bayesian ANOVA provides credible intervals (credible regions), which give the range of values for the parameter based on the posterior distribution and have a direct probabilistic interpretation (e.g., there is a 95% probability that the parameter lies within the interval).

# %% [raw]
# 8. Question: You have two sets of data representing the incomes of two different professions1
# V Profession A: [48, 52, 55, 60, 62'
# V Profession B: [45, 50, 55, 52, 47] Perform an F-test to determine if the variances of the two professions'
# incomes are equal. What are your conclusions based on the F-test?
#
# Task: Use Python to calculate the F-statistic and p-value for the given data.
#
# Objective: Gain experience in performing F-tests and interpreting the results in terms of variance comparison

# %%
#Ans.
import numpy as np
from scipy import stats

# Data
profession_a = np.array([48, 52, 55, 60, 62])
profession_b = np.array([45, 50, 55, 52, 47])

# Step 1: Calculate the sample variances
var_a = np.var(profession_a, ddof=1)  # Sample variance of Profession A
var_b = np.var(profession_b, ddof=1)  # Sample variance of Profession B

# Step 2: Calculate the F-statistic (ratio of variances)
# Ensure the larger variance is in the numerator
if var_a > var_b:
    f_statistic = var_a / var_b
    df1 = len(profession_a) - 1  # Degrees of freedom for Profession A
    df2 = len(profession_b) - 1  # Degrees of freedom for Profession B
else:
    f_statistic = var_b / var_a
    df1 = len(profession_b) - 1  # Degrees of freedom for Profession B
    df2 = len(profession_a) - 1  # Degrees of freedom for Profession A

# Step 3: Calculate the p-value for the F-test
p_value = 2 * min(stats.f.cdf(f_statistic, df1, df2), 1 - stats.f.cdf(f_statistic, df1, df2))

# Output the results
print(f"Variance of Profession A: {var_a}")
print(f"Variance of Profession B: {var_b}")
print(f"F-statistic: {f_statistic}")
print(f"Degrees of freedom for Profession A: {df1}")
print(f"Degrees of freedom for Profession B: {df2}")
print(f"p-value: {p_value}")

# Conclusion based on the p-value
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis: The variances of the two professions are significantly different.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the variances of the two professions.")
# Out:
# Variance of Profession A: 32.8
# Variance of Profession B: 15.7
# F-statistic: 2.089171974522293
# Degrees of freedom for Profession A: 4
# Degrees of freedom for Profession B: 4
# p-value: 0.49304859900533904
# Fail to reject the null hypothesis: There is no significant difference between the variances of the two professions.

# %% [raw]
# 9. Question: Conduct a one-way ANOVA to test whether there are any statistically significant differences in
# average heights between three different regions with the following data1
# V Region A: [160, 162, 165, 158, 164'
# V Region B: [172, 175, 170, 168, 174'
# V Region C: [180, 182, 179, 185, 183'
# V Task: Write Python code to perform the one-way ANOVA and interpret the results
# V Objective: Learn how to perform one-way ANOVA using Python and interpret F-statistic and p-value.

# %%
#Ans.
import scipy.stats as stats

# Data for the three regions
region_a = [160, 162, 165, 158, 164]
region_b = [172, 175, 170, 168, 174]
region_c = [180, 182, 179, 185, 183]

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(region_a, region_b, region_c)

# Output the results
print("F-statistic:", f_statistic)
print("P-value:", p_value)

# Interpret the result
alpha = 0.05  # Significance level (5%)
if p_value < alpha:
    print("Reject the null hypothesis: There are significant differences between the regions.")
else:
    print("Fail to reject the null hypothesis: There are no significant differences between the regions.")
# Out:
# F-statistic: 67.87330316742101
# P-value: 2.870664187937026e-07
# Reject the null hypothesis: There are significant differences between the regions.
